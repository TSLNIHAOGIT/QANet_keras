# %%
ls
# Out:
# QANet_fit_demo.py              func_test.ipynb  preprocess.py
# QANet_keras.py                 layers/          process.ipynb
# README.md*                     model/           qanet_all_program.ipynb
# __pycache__/                   old_preprocess/  train_QANet.py
# func_full_program.ipynb        original_data/   utils/
# func_full_program_cloze.ipynb  picture/

# %%
# !python3 preprocess.py
# Out:
# ...
# 100%|███████████████████████████████████| 98451/98451 [00:31<00:00, 3131.50it/s]
# UNK / HIT : 53150 / 48902
# CHAR num : 1414
#   2%|▋                               | 48902/2200000 [00:04<03:20, 10720.91it/s]
# (48904, 300)
# 48904
# (1416, 64)
# 1416
#   0%|▏                                    | 371/87738 [00:00<00:46, 1865.27it/s]index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# ...
